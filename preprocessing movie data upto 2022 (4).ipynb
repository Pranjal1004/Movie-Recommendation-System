# %% [markdown]
# ### Just like preprocessing 3, we'll scrape movie data for 2022 using wikipead and TMDB and add it to "movie_data_upto_2021.csv".

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Extracting some features of 2022 movies from Wikipedia
# #### NOTE: We won't scrape the entire data for 2022 as the year hasn't ended yet. We'll scrape data of only those movies, which have been relesed.

# %%
# extracting tables from wikipedia page
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"
#  the argument 2,3,4,5 here indicates the table number
# We are adding movie data only upto march as the rest of the movie hasn't released yet
t1_2022 = pd.read_html(link, header=0)[3]

# %%
table_2022 = t1_2022[["Title", "Cast and crew"]]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = "4bfa18d4dd4f5d041a3d88cfb6728654"

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def extract_genres(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
        # This "if not result" condition is specifically added for 2020 data as for some movie we don't get result on TMBb
        return np.NaN
    else:
        movie_id = result[0].id
        response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
        # extracting data in json format
        data_json = response.json()
        if data_json['genres']:
        # Actually there's a key "genres" which basically holds a list of dictionaries and each dictionary has one genre
        # paired to key "name". So we here loop thorugh each dictionary and extract each & every genre of a given movie.    
            genre_str = " " 
            for i in range(0,len(data_json['genres'])):
                genres.append(data_json['genres'][i]['name'])
            return genre_str.join(genres)
        else:
            return np.NaN

# %%
table_2022['genres'] = table_2022['Title'].map(lambda x: extract_genres(str(x)))
# Out:
# C:\Users\pranj\AppData\Local\Temp\ipykernel_7636\3180849025.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table_2022['genres'] = table_2022['Title'].map(lambda x: extract_genres(str(x)))

# %%
table_2022.head()
# Out:
#                                Title  \
# 0                            The 355
# 1           The Legend of La Llorona
# 2                       The Commando
# 3                             Scream
# 4  Hotel Transylvania: Transformania
#
#                                        Cast and crew  \
# 0  Simon Kinberg (director/screenplay); Theresa R...
# 1  Patricia Harris Seeley (director/screenplay); ...
# 2  Asif Akbar (director); Koji Steven Sakai (scre...
# 3  Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4  Jennifer Kluska, Derek Drymon (directors); Amo...
#
#                                       genres
# 0                            Action Thriller
# 1                            Horror Thriller
# 2                      Action Crime Thriller
# 3                    Horror Mystery Thriller
# 4  Animation Family Fantasy Comedy Adventure

# %%
movie_data_2022_march = table_2022

# %%
def extract_director_name(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (director/screenplay)" in x:
        return x.split(" (director/screenplay)")[0]
    # This " (directors/screenplay)" & " (directors)" condition is specifically added for 2022 data.
    elif " (directors/screenplay)" in x:
        directors = x.split(" (directors/screenplay)")[0]
        directors_list = directors.split(", ")
        return " ".join(directors_list)
    elif " (directors)" in x:
        directors = x.split(" (directors)")[0]
        directors_list = directors.split(", ")
        return " ".join(directors_list)
    else:
        return x.split(" (directors)")[0]

# %%
movie_data_2022_march["director_name"] = movie_data_2022_march["Cast and crew"].map(lambda x: extract_director_name(x))
# Out:
# C:\Users\pranj\AppData\Local\Temp\ipykernel_7636\2714104579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_data_2022_march["director_name"] = movie_data_2022_march["Cast and crew"].map(lambda x: extract_director_name(x))

# %%
def extract_actor_names(x, actor_num):
    # here we are separating actor names from rest of the crew.    
    cast = x.split("screenplay); ")[-1]
    if actor_num == 0:
        return cast.split(", ")[actor_num]
    elif actor_num == 1:
        if len(cast.split(", ")) < 2:
            return np.NaN
        else:
            return cast.split(", ")[actor_num]
    elif actor_num == 2:
        if len(cast.split(", ")) < 3:
            return np.NaN
        else:
            return cast.split(", ")[actor_num]

# %%
movie_data_2022_march["actor_1_name"] = movie_data_2022_march["Cast and crew"].map(lambda x: extract_actor_names(x, 0))
# Out:
# C:\Users\pranj\AppData\Local\Temp\ipykernel_7636\3440772467.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_data_2022_march["actor_1_name"] = movie_data_2022_march["Cast and crew"].map(lambda x: extract_actor_names(x, 0))

# %%
movie_data_2022_march["actor_2_name"] = movie_data_2022_march["Cast and crew"].map(lambda x: extract_actor_names(x, 1))

# %%
movie_data_2022_march["actor_3_name"] = movie_data_2022_march["Cast and crew"].map(lambda x: extract_actor_names(x, 2))

# %%
movie_data_2022_march
# Out:
#                                 Title  \
# 0                             The 355
# 1            The Legend of La Llorona
# 2                        The Commando
# 3                              Scream
# 4   Hotel Transylvania: Transformania
# ..                                ...
# 56                      The Lost City
# 57  Everything Everywhere All at Once
# 58                     Infinite Storm
# 59                             7 Days
# 60                           Moonshot
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Patricia Harris Seeley (director/screenplay); ...
# 2   Asif Akbar (director); Koji Steven Sakai (scre...
# 3   Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4   Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                ...
# 56  Aaron Nee, Adam Nee (directors/screenplay); Or...
# 57  Daniel Kwan, Daniel Scheinert (directors/scree...
# 58  Małgorzata Szumowska, Michał Englert (director...
# 59  Roshan Sethi (director/screenplay); Karan Soni...
# 60  Chris Winterbauer (director); Max Taxe (screen...
#
#                                        genres  \
# 0                             Action Thriller
# 1                             Horror Thriller
# 2                       Action Crime Thriller
# 3                     Horror Mystery Thriller
# 4   Animation Family Fantasy Comedy Adventure
# ..                                        ...
# 56            Action Adventure Comedy Romance
# 57              Action Science Fiction Comedy
# 58                             Drama Thriller
# 59                       Thriller Drama Crime
# 60             Comedy Romance Science Fiction
#
#                            director_name      actor_1_name  \
# 0                          Simon Kinberg  Jessica Chastain
# 1                 Patricia Harris Seeley     Autumn Reeser
# 2                             Asif Akbar     Mickey Rourke
# 3   Matt Bettinelli-Olpin, Tyler Gillett   Melissa Barrera
# 4           Jennifer Kluska Derek Drymon      Andy Samberg
# ..                                   ...               ...
# 56                    Aaron Nee Adam Nee    Sandra Bullock
# 57          Daniel Kwan Daniel Scheinert     Michelle Yeoh
# 58   Małgorzata Szumowska Michał Englert       Naomi Watts
# 59                          Roshan Sethi        Karan Soni
# 60                     Chris Winterbauer      Cole Sprouse
#
#              actor_2_name      actor_3_name
# 0          Lupita Nyong'o     Penélope Cruz
# 1            Antonio Cupo       Danny Trejo
# 2       Michael Jai White               NaN
# 3           Mason Gooding      Jenna Ortega
# 4            Selena Gomez      Kathryn Hahn
# ..                    ...               ...
# 56         Channing Tatum  Daniel Radcliffe
# 57          Stephanie Hsu       Ke Huy Quan
# 58            Billy Howle    Sophie Okonedo
# 59  Geraldine Viswanathan      Mark Duplass
# 60            Lana Condor     Mason Gooding
#
# [61 rows x 7 columns]

# %%
movie_data_2022_march = movie_data_2022_march.rename(columns={"Title": "movie_title"})

# %%
new_movie_data_2022_march = movie_data_2022_march.loc[:, ["movie_title", "genres", "director_name", "actor_1_name", "actor_2_name", "actor_3_name"]]

# %%
new_movie_data_2022_march["actor_2_name"] = new_movie_data_2022_march["actor_2_name"].replace(np.NaN, "unknown")
new_movie_data_2022_march["actor_3_name"] = new_movie_data_2022_march["actor_3_name"].replace(np.NaN, "unknown")

# %%
new_movie_data_2022_march["movie_title"] = new_movie_data_2022_march["movie_title"].str.lower()

# %%
new_movie_data_2022_march["combine"] = new_movie_data_2022_march["genres"] +" "+ new_movie_data_2022_march["director_name"] +" "+ new_movie_data_2022_march["actor_1_name"] +" "+ new_movie_data_2022_march["actor_2_name"] +" "+new_movie_data_2022_march["actor_3_name"]

# %%
new_movie_data_2022_march
# Out:
#                           movie_title  \
# 0                             the 355
# 1            the legend of la llorona
# 2                        the commando
# 3                              scream
# 4   hotel transylvania: transformania
# ..                                ...
# 56                      the lost city
# 57  everything everywhere all at once
# 58                     infinite storm
# 59                             7 days
# 60                           moonshot
#
#                                        genres  \
# 0                             Action Thriller
# 1                             Horror Thriller
# 2                       Action Crime Thriller
# 3                     Horror Mystery Thriller
# 4   Animation Family Fantasy Comedy Adventure
# ..                                        ...
# 56            Action Adventure Comedy Romance
# 57              Action Science Fiction Comedy
# 58                             Drama Thriller
# 59                       Thriller Drama Crime
# 60             Comedy Romance Science Fiction
#
#                            director_name      actor_1_name  \
# 0                          Simon Kinberg  Jessica Chastain
# 1                 Patricia Harris Seeley     Autumn Reeser
# 2                             Asif Akbar     Mickey Rourke
# 3   Matt Bettinelli-Olpin, Tyler Gillett   Melissa Barrera
# 4           Jennifer Kluska Derek Drymon      Andy Samberg
# ..                                   ...               ...
# 56                    Aaron Nee Adam Nee    Sandra Bullock
# 57          Daniel Kwan Daniel Scheinert     Michelle Yeoh
# 58   Małgorzata Szumowska Michał Englert       Naomi Watts
# 59                          Roshan Sethi        Karan Soni
# 60                     Chris Winterbauer      Cole Sprouse
#
#              actor_2_name      actor_3_name  \
# 0          Lupita Nyong'o     Penélope Cruz
# 1            Antonio Cupo       Danny Trejo
# 2       Michael Jai White           unknown
# 3           Mason Gooding      Jenna Ortega
# 4            Selena Gomez      Kathryn Hahn
# ..                    ...               ...
# 56         Channing Tatum  Daniel Radcliffe
# 57          Stephanie Hsu       Ke Huy Quan
# 58            Billy Howle    Sophie Okonedo
# 59  Geraldine Viswanathan      Mark Duplass
# 60            Lana Condor     Mason Gooding
#
#                                               combine
# 0   Action Thriller Simon Kinberg Jessica Chastain...
# 1   Horror Thriller Patricia Harris Seeley Autumn ...
# 2   Action Crime Thriller Asif Akbar Mickey Rourke...
# 3   Horror Mystery Thriller Matt Bettinelli-Olpin,...
# 4   Animation Family Fantasy Comedy Adventure Jenn...
# ..                                                ...
# 56  Action Adventure Comedy Romance Aaron Nee Adam...
# 57  Action Science Fiction Comedy Daniel Kwan Dani...
# 58  Drama Thriller Małgorzata Szumowska Michał Eng...
# 59  Thriller Drama Crime Roshan Sethi Karan Soni G...
# 60  Comedy Romance Science Fiction Chris Winterbau...
#
# [61 rows x 7 columns]

# %%
movie_data_upto_2021 = pd.read_csv("movie_data_upto_2021.csv")

# %%
movie_data_upto_2021
# Out:
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6500                                     the king's man
# 6501                             the tragedy of macbeth
# 6502                               a journal for jordan
# 6503                                  american underdog
# 6504                                            memoria
#
#                                      genres  \
# 0           Action Adventure Fantasy Sci-Fi
# 1                  Action Adventure Fantasy
# 2                 Action Adventure Thriller
# 3                           Action Thriller
# 4                               Documentary
# ...                                     ...
# 6500  Action Adventure Thriller War Mystery
# 6501                              Drama War
# 6502                          Drama Romance
# 6503                                  Drama
# 6504                  Drama Fantasy Mystery
#
#                                           director_name  \
# 0                                         James Cameron
# 1                                        Gore Verbinski
# 2                                            Sam Mendes
# 3                                     Christopher Nolan
# 4                                           Doug Walker
# ...                                                 ...
# 6500                                     Matthew Vaughn
# 6501                                          Joel Coen
# 6502                                  Denzel Washington
# 6503                                     Erwin brothers
# 6504  Apichatpong Weerasethakul (director/acreenplay...
#
#                                            actor_1_name       actor_2_name  \
# 0                                           CCH Pounder   Joel David Moore
# 1                                           Johnny Depp      Orlando Bloom
# 2                                       Christoph Waltz       Rory Kinnear
# 3                                             Tom Hardy     Christian Bale
# 4                                           Doug Walker         Rob Walker
# ...                                                 ...                ...
# 6500                                      Ralph Fiennes     Gemma Arterton
# 6501                                  Denzel Washington  Frances McDormand
# 6502                                  Michael B. Jordan       Chanté Adams
# 6503                                       Zachary Levi        Anna Paquin
# 6504  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#               actor_3_name                                            combine
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi James Cameron ...
# 1           Jack Davenport  Action Adventure Fantasy Gore Verbinski Johnny...
# 2         Stephanie Sigman  Action Adventure Thriller Sam Mendes Christoph...
# 3     Joseph Gordon-Levitt  Action Thriller Christopher Nolan Tom Hardy Ch...
# 4                  unknown  Documentary Doug Walker Doug Walker Rob Walker...
# ...                    ...                                                ...
# 6500            Rhys Ifans  Action Adventure Thriller War Mystery Matthew ...
# 6501         Bertie Carvel  Drama War Joel Coen Denzel Washington Frances ...
# 6502       Jalon Christian  Drama Romance Denzel Washington Michael B. Jor...
# 6503          Dennis Quaid  Drama Erwin brothers Zachary Levi Anna Paquin ...
# 6504        Jeanne Balibar  Drama Fantasy Mystery Apichatpong Weerasethaku...
#
# [6505 rows x 7 columns]

# %%
movie_data_upto_2022_march = movie_data_upto_2021.append(new_movie_data_2022_march, ignore_index=True)

# %%
movie_data_upto_2022_march
# Out:
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6561                                      the lost city
# 6562                  everything everywhere all at once
# 6563                                     infinite storm
# 6564                                             7 days
# 6565                                           moonshot
#
#                                genres                        director_name  \
# 0     Action Adventure Fantasy Sci-Fi                        James Cameron
# 1            Action Adventure Fantasy                       Gore Verbinski
# 2           Action Adventure Thriller                           Sam Mendes
# 3                     Action Thriller                    Christopher Nolan
# 4                         Documentary                          Doug Walker
# ...                               ...                                  ...
# 6561  Action Adventure Comedy Romance                   Aaron Nee Adam Nee
# 6562    Action Science Fiction Comedy         Daniel Kwan Daniel Scheinert
# 6563                   Drama Thriller  Małgorzata Szumowska Michał Englert
# 6564             Thriller Drama Crime                         Roshan Sethi
# 6565   Comedy Romance Science Fiction                    Chris Winterbauer
#
#          actor_1_name           actor_2_name          actor_3_name  \
# 0         CCH Pounder       Joel David Moore             Wes Studi
# 1         Johnny Depp          Orlando Bloom        Jack Davenport
# 2     Christoph Waltz           Rory Kinnear      Stephanie Sigman
# 3           Tom Hardy         Christian Bale  Joseph Gordon-Levitt
# 4         Doug Walker             Rob Walker               unknown
# ...               ...                    ...                   ...
# 6561   Sandra Bullock         Channing Tatum      Daniel Radcliffe
# 6562    Michelle Yeoh          Stephanie Hsu           Ke Huy Quan
# 6563      Naomi Watts            Billy Howle        Sophie Okonedo
# 6564       Karan Soni  Geraldine Viswanathan          Mark Duplass
# 6565     Cole Sprouse            Lana Condor         Mason Gooding
#
#                                                 combine
# 0     Action Adventure Fantasy Sci-Fi James Cameron ...
# 1     Action Adventure Fantasy Gore Verbinski Johnny...
# 2     Action Adventure Thriller Sam Mendes Christoph...
# 3     Action Thriller Christopher Nolan Tom Hardy Ch...
# 4     Documentary Doug Walker Doug Walker Rob Walker...
# ...                                                 ...
# 6561  Action Adventure Comedy Romance Aaron Nee Adam...
# 6562  Action Science Fiction Comedy Daniel Kwan Dani...
# 6563  Drama Thriller Małgorzata Szumowska Michał Eng...
# 6564  Thriller Drama Crime Roshan Sethi Karan Soni G...
# 6565  Comedy Romance Science Fiction Chris Winterbau...
#
# [6566 rows x 7 columns]

# %%
movie_data_upto_2022_march.isna().sum()
# Out:
# movie_title      0
# genres           0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# combine          0
# dtype: int64

# %%
movie_data_upto_2022_march.movie_title = movie_data_upto_2022_march.movie_title.str.strip()
# removing "leading and trailing space" and also the "null terminationg character(\xa0)" of the column

# %%
movie_data_upto_2022_march.to_csv("movie_data_upto_2022_march.csv", index= False)
